# %% [markdown]
# #Step 1: Load and Explore the Dataset

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 

data = pd.read_csv("delhi-air-pollution.csv")
df = pd.DataFrame(data) #It wil convert the dataset into DataFrame
df.head(10) #it will print 1st 10 row of the dataset
# Out:
#    Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0     1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1     2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2     3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3     4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4     5      1  2021               0     2   54.06   55.54  122.66   9.70
# 5     6      1  2021               0     3  155.59  180.14  142.71  10.29
# 6     7      1  2021               0     4  118.39  131.18   98.87   9.81
# 7     8      1  2021               0     5  140.05  184.29  102.61  10.34
# 8     9      1  2021               0     6  144.01  192.43  108.43  10.41
# 9    10      1  2021               1     7  131.57  180.38   93.31   9.92
#
#      CO  Ozone  AQI
# 0  2.77  43.19  462
# 1  2.60  16.43  482
# 2  1.40  44.29  263
# 3  1.01  49.19  207
# 4  0.64  48.88  149
# 5  1.18  44.47  252
# 6  0.73  48.60  288
# 7  0.79  43.06  248
# 8  0.85  42.23  326
# 9  0.69  51.96  284

# %%
df.info() #Will show the number columns and necessory information
df.describe() #Will count all the basic methods for the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1461 non-null   int64
#  1   Month           1461 non-null   int64
#  2   Year            1461 non-null   int64
#  3   Holidays_Count  1461 non-null   int64
#  4   Days            1461 non-null   int64
#  5   PM2.5           1461 non-null   float64
#  6   PM10            1461 non-null   float64
#  7   NO2             1461 non-null   float64
#  8   SO2             1461 non-null   float64
#  9   CO              1461 non-null   float64
#  10  Ozone           1461 non-null   float64
#  11  AQI             1461 non-null   int64
# dtypes: float64(6), int64(6)
# memory usage: 137.1 KB
#               Date        Month         Year  Holidays_Count         Days  \
# count  1461.000000  1461.000000  1461.000000     1461.000000  1461.000000
# mean     15.729637     6.522930  2022.501027        0.189596     4.000684
# std       8.803105     3.449884     1.118723        0.392116     2.001883
# min       1.000000     1.000000  2021.000000        0.000000     1.000000
# 25%       8.000000     4.000000  2022.000000        0.000000     2.000000
# 50%      16.000000     7.000000  2023.000000        0.000000     4.000000
# 75%      23.000000    10.000000  2024.000000        0.000000     6.000000
# max      31.000000    12.000000  2024.000000        1.000000     7.000000
#
#              PM2.5         PM10          NO2          SO2           CO  \
# count  1461.000000  1461.000000  1461.000000  1461.000000  1461.000000
# mean     90.774538   218.219261    37.184921    20.104921     1.025832
# std      71.650579   129.297734    35.225327    16.543659     0.608305
# min       0.050000     9.690000     2.160000     1.210000     0.270000
# 25%      41.280000   115.110000    17.280000     7.710000     0.610000
# 50%      72.060000   199.800000    30.490000    15.430000     0.850000
# 75%     118.500000   297.750000    45.010000    26.620000     1.240000
# max    1000.000000  1000.000000   433.980000   113.400000     4.700000
#
#              Ozone          AQI
# count  1461.000000  1461.000000
# mean     36.338871   202.210815
# std      18.951204   107.801076
# min       2.700000    19.000000
# 25%      24.100000   108.000000
# 50%      32.470000   189.000000
# 75%      45.730000   284.000000
# max     115.870000   500.000000

# %%
print(df[["PM2.5" , "PM10"]].fillna(0)) #This will fill the null values by 0
print(df.isnull().sum()) #This will show the total sum of null values
# Out:
#        PM2.5    PM10
# 0     408.80  442.42
# 1     404.04  561.95
# 2     225.07  239.04
# 3      89.55  132.08
# 4      54.06   55.54
# ...      ...     ...
# 1456   58.43  249.17
# 1457   33.83  150.77
# 1458   31.21  139.75
# 1459   38.01  152.83
# 1460   80.42  318.96
#
# [1461 rows x 2 columns]
# Date              0
# Month             0
# Year              0
# Holidays_Count    0
# Days              0
# PM2.5             0
# PM10              0
# NO2               0
# SO2               0
# CO                0
# Ozone             0
# AQI               0
# dtype: int64

# %% [markdown]
# #Step 2: Data Cleaning

# %%
df_filtered = df[(df['Year'] >= 2020) & (df['Year'] <= 2024)]
df_filtered
# Out:
#       Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0        1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1        2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2        3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3        4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4        5      1  2021               0     2   54.06   55.54  122.66   9.70
# ...    ...    ...   ...             ...   ...     ...     ...     ...    ...
# 1456    27     12  2024               0     5   58.43  249.17   41.69  65.89
# 1457    28     12  2024               0     6   33.83  150.77   33.31  66.14
# 1458    29     12  2024               1     7   31.21  139.75   27.01  65.94
# 1459    30     12  2024               0     1   38.01  152.83   29.12  65.16
# 1460    31     12  2024               0     2   80.42  318.96   40.37  64.98
#
#         CO  Ozone  AQI
# 0     2.77  43.19  462
# 1     2.60  16.43  482
# 2     1.40  44.29  263
# 3     1.01  49.19  207
# 4     0.64  48.88  149
# ...    ...    ...  ...
# 1456  0.99  36.25  263
# 1457  0.79  35.19  113
# 1458  0.57  35.88  142
# 1459  0.55  38.38  116
# 1460  0.84  39.93  209
#
# [1461 rows x 12 columns]

# %% [markdown]
# #Step 3:
# Part A: Analysis part

# %%
grouped = df.groupby(['Month' , 'Year'])[["PM2.5" , "PM10" , "NO2" , "AQI"]].mean().reset_index() #This will group the data into month and year and then count the mean of each group
#rouped.head(20)   #It print the first 20 rows 
grouped.sample(20) #It will print random 20 rows from the dataset
# Out:
#     Month  Year       PM2.5        PM10        NO2         AQI
# 16      5  2021   61.549677  148.422903  43.834839  135.225806
# 39     10  2024   67.648065  245.140323  45.252581  207.064516
# 5       2  2022  115.178571  200.186786  27.011429  228.964286
# 34      9  2023   32.280667  101.500667  27.923000   95.066667
# 14      4  2023   54.930333  205.501667  29.704000  188.133333
# 23      6  2024  120.066667  233.225667  42.176333  192.233333
# 13      4  2022  161.924667  319.483000  27.584000  287.666667
# 26      7  2023   36.902258   81.383548  20.089677   78.516129
# 46     12  2023  102.198065  344.461935  63.205806  291.741935
# 47     12  2024   85.452258  326.304839  50.727419  265.322581
# 28      8  2021   46.307742  108.047419  26.472581  105.387097
# 20      6  2021   57.933000  164.143000  48.138667  141.300000
# 45     12  2022  112.242581  323.183871  43.163871  271.612903
# 31      8  2024   15.478710   57.229355  40.269677   59.354839
# 18      5  2023   57.560000  194.251613  25.176129  174.193548
# 22      6  2023   44.796667  130.865667  21.399667  119.400000
# 40     11  2021  243.365000  331.035000  41.830667  372.700000
# 35      9  2024   25.869333   98.516000  40.821333   94.500000
# 41     11  2022  108.672000  370.920333  52.119333  310.166667
# 2       1  2023  158.010000  315.732581  11.979355  295.451613

# %% [markdown]
# #Step 3:
# Part B:Pollution Severity Categorization

# %%
conditions = [
    (df['AQI'] <= 50),
    (df['AQI'] >= 50) & (df['AQI'] <= 100),
    (df['AQI'] >= 101) & (df['AQI'] <= 200),
    (df['AQI'] >= 201) & (df['AQI'] <= 300),
    (df['AQI'] >= 301) & (df['AQI'] <= 400),
    (df['AQI'] >= 401)
]

choices = [
    'Good',
    'Satisfactory',
    'Moderate',
    'Poor',
    'Very',
    'Severe'
]

df["aqi_categories"] = np.select(conditions , choices , default='Unknown') #it will categorize the whole dataset into above categories
df["aqi_categories"].sample(20)
# Out:
# 1283    Satisfactory
# 804             Poor
# 1314            Good
# 202     Satisfactory
# 757         Moderate
# 946     Satisfactory
# 1173            Poor
# 1231            Poor
# 355           Severe
# 836             Poor
# 639         Moderate
# 360             Poor
# 1194            Poor
# 476         Moderate
# 996         Moderate
# 1263        Moderate
# 1068            Poor
# 1169        Moderate
# 159             Very
# 792         Moderate
# Name: aqi_categories, dtype: object

# %% [markdown]
# Step 3:
# Part C: Peak Pollution Periods

# %%
top_5_polluted = df.sort_values(by='AQI', ascending=False).head(5)
top_5_polluted
# Out:
#      Date  Month  Year  Holidays_Count  Days   PM2.5     PM10     NO2    SO2  \
# 737     8      1  2023               1     7  232.78   869.48    9.26   5.16
# 736     7      1  2023               0     6  200.60  1000.00   13.16  15.77
# 359    26     12  2021               1     7  432.88   595.44   26.81   3.25
# 315    12     11  2021               0     5  387.18   451.81  101.76   7.96
# 1       2      1  2021               0     6  404.04   561.95   52.85   5.18
#
#        CO  Ozone  AQI aqi_categories
# 737  1.52  50.96  500         Severe
# 736  1.15  41.66  500         Severe
# 359  2.02   7.09  490         Severe
# 315  4.02  23.80  489         Severe
# 1    2.60  16.43  482         Severe

# %%
pm25_avg = df.groupby(['Month' , 'Year'])['PM2.5'].mean().reset_index()
max_pm25 = pm25_avg.loc[pm25_avg['PM2.5'].idxmax()]
max_pm25
# Out:
# Month      11.000
# Year     2021.000
# PM2.5     243.365
# Name: 40, dtype: float64

# %% [markdown]
# #Step 4: Visualization

# %%
# 📈 Line Plot
# Monthly average PM2.5 and PM10 trends (2020–2.024)

sns.lineplot(x='PM2.5' , y='PM10' , data = df , hue = 'aqi_categories')
plt.title("Monthly average PM2.5 and PM10 trends (2020–2.024)")
plt.show()

# %%
# 📊 Bar Chart
# Average AQI per year.
plt.figure(figsize=(8,6))
avg_years = df.groupby('Year')['AQI'].mean().reset_index()
sns.barplot( data = avg_years , x='AQI' , y='Year')
plt.title("Average AQI Per Year")
plt.xlabel("Average AQI")
plt.ylabel("Year")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# import matplotlib.pyplot as plt

# Group PM2.5 by year
years = sorted(df['Year'].unique())
data_by_year = [df[df['Year'] == year]['PM2.5'].dropna() for year in years]

plt.figure(figsize=(10, 6))
plt.boxplot(data_by_year, labels=years)
plt.title('PM2.5 Spread by Year')
plt.xlabel('Year')
plt.ylabel('PM2.5 Concentration')
plt.grid(True)
plt.show()
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_25396\531334439.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_by_year, labels=years)

# %%
pollutants = ['PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'Ozone', 'AQI']
corr_matrix = df[pollutants].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap Between Pollutants')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(df['AQI'].dropna(), shade=True, color='red')
plt.title('AQI Distribution (KDE)')
plt.xlabel('Air Quality Index')
plt.ylabel('Density')
plt.grid(True)
plt.show()
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_25396\641463747.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['AQI'].dropna(), shade=True, color='red')
